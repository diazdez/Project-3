# %%
import pandas as pd

# %%
borrower_df = pd.read_csv('resources/borrower_table.csv')

# %%
borrower_df
# Out:
#         loan_id  is_first_loan  fully_repaid_previous_loans  \
# 0        289774              1                          NaN
# 1        482590              0                          1.0
# 2        135565              1                          NaN
# 3        207797              0                          1.0
# 4        828078              0                          0.0
# ...         ...            ...                          ...
# 101095    38238              1                          NaN
# 101096   590712              1                          NaN
# 101097   961276              1                          NaN
# 101098   551027              0                          1.0
# 101099   761999              1                          NaN
#
#         currently_repaying_other_loans  total_credit_card_limit  \
# 0                                  NaN                     8000
# 1                                  0.0                     4500
# ...

# %%
loan_df = pd.read_csv('resources/loan_table.csv')

# %%
loan_df
# Out:
#         loan_id     loan_purpose        date  loan_granted  loan_repaid
# 0         19454       investment  2012-03-15             0          NaN
# 1        496811       investment  2012-01-17             0          NaN
# 2        929493            other  2012-02-09             0          NaN
# 3        580653            other  2012-06-27             1          1.0
# 4        172419         business  2012-05-21             1          0.0
# ...         ...              ...         ...           ...          ...
# 101095   734902  emergency_funds  2012-01-30             1          0.0
# 101096   712467         business  2012-11-22             1          0.0
# 101097   209268            other  2012-09-13             1          1.0
# 101098   779254         business  2012-02-08             1          1.0
# 101099   774414            other  2012-05-09             0          NaN
#
# [101100 rows x 5 columns]

# %%
combined_df = pd.merge(borrower_df,loan_df, on='loan_id',how='inner')

# %%
combined_df.columns
# Out:
# Index(['loan_id', 'is_first_loan', 'fully_repaid_previous_loans',
#        'currently_repaying_other_loans', 'total_credit_card_limit',
#        'avg_percentage_credit_card_limit_used_last_year', 'saving_amount',
#        'checking_amount', 'is_employed', 'yearly_salary', 'age',
#        'dependent_number', 'loan_purpose', 'date', 'loan_granted',
#        'loan_repaid'],
#       dtype='object')

# %%
combined_df.to_csv('resources/combined_loan.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bb048925d19d> in <module>
# ----> 1 combined_df.to_csv('resources/combined_loan.csv',index=False)
#
# NameError: name 'combined_df' is not defined

# %%
combined_df = pd.read_csv('resources/combined_loan.csv')

# %%
combined_df_y = combined_df.loc[combined_df['loan_repaid']==1]

# %%
combined_df_y.to_csv('resources/combined_loan_y.csv',index = False)

# %%
pd.read_csv('resources/combined_loan_y.csv')
# Out:
#        loan_id  is_first_loan  fully_repaid_previous_loans  \
# 0       135565              1                          NaN
# 1       423171              1                          NaN
# 2       991294              0                          1.0
# 3       875332              0                          1.0
# 4       954215              1                          NaN
# ...        ...            ...                          ...
# 30701   106237              0                          1.0
# 30702   352484              1                          NaN
# 30703    17749              0                          0.0
# 30704   590712              1                          NaN
# 30705   761999              1                          NaN
#
#        currently_repaying_other_loans  total_credit_card_limit  \
# 0                                 NaN                     6900
# 1                                 NaN                     6100
# 2                                 0.0                     7000
# ...
